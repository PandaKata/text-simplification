# %%
import sys
print(sys.executable)
# Out:
# /Users/kata/opt/anaconda3/bin/python

# %%
import datasets
import pandas as pd

# %%
all_ds = datasets.list_datasets()
len(all_ds)
# Out:
# 7351

# %%
"wiki_auto" in all_ds
# Out:
# True

# %%
dataset = datasets.load_dataset('wiki_auto', 'manual')
# Out:
# Downloading and preparing dataset wiki_auto/manual (download: 161.13 MiB, generated: 158.12 MiB, post-processed: Unknown size, total: 319.25 MiB) to /Users/kata/.cache/huggingface/datasets/wiki_auto/manual/1.0.0/eeac705719dc9aa2ff180571dfed6c6649588ccdfde8d45a47d2e47e5c5b93af...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/113M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.00M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.79M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/373801 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/73249 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/118074 [00:00<?, ? examples/s]
# Dataset wiki_auto downloaded and prepared to /Users/kata/.cache/huggingface/datasets/wiki_auto/manual/1.0.0/eeac705719dc9aa2ff180571dfed6c6649588ccdfde8d45a47d2e47e5c5b93af. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['alignment_label', 'normal_sentence_id', 'simple_sentence_id', 'normal_sentence', 'simple_sentence', 'gleu_score'],
#         num_rows: 373801
#     })
#     dev: Dataset({
#         features: ['alignment_label', 'normal_sentence_id', 'simple_sentence_id', 'normal_sentence', 'simple_sentence', 'gleu_score'],
#         num_rows: 73249
#     })
#     test: Dataset({
#         features: ['alignment_label', 'normal_sentence_id', 'simple_sentence_id', 'normal_sentence', 'simple_sentence', 'gleu_score'],
#         num_rows: 118074
#     })
# })

# %%
train_ds = dataset['train']
test_ds = dataset['test']
dev_ds = dataset['dev']

# %%
print(train_ds)
print(test_ds)
print(dev_ds)
# Out:
# Dataset({
#     features: ['alignment_label', 'normal_sentence_id', 'simple_sentence_id', 'normal_sentence', 'simple_sentence', 'gleu_score'],
#     num_rows: 373801
# })
# Dataset({
#     features: ['alignment_label', 'normal_sentence_id', 'simple_sentence_id', 'normal_sentence', 'simple_sentence', 'gleu_score'],
#     num_rows: 118074
# })
# Dataset({
#     features: ['alignment_label', 'normal_sentence_id', 'simple_sentence_id', 'normal_sentence', 'simple_sentence', 'gleu_score'],
#     num_rows: 73249
# })

# %%
dataset['train'][15]
# Out:
# {'alignment_label': 0,
#  'normal_sentence_id': '0_66252-1-3-1',
#  'simple_sentence_id': '0_66252-0-0-0',
#  'normal_sentence': 'Part III of the Act also set up the Inner London Education Authority, which had previously been a committee of the GLC responsible for education in Inner London, as a directly elected body.',
#  'simple_sentence': 'The Local Government Act 1985 was an Act of Parliament in the United Kingdom.',
#  'gleu_score': 0.0396825410425663}

# %%
train_ds.features
# Out:
# {'alignment_label': ClassLabel(num_classes=3, names=['notAligned', 'aligned', 'partialAligned'], id=None),
#  'normal_sentence_id': Value(dtype='string', id=None),
#  'simple_sentence_id': Value(dtype='string', id=None),
#  'normal_sentence': Value(dtype='string', id=None),
#  'simple_sentence': Value(dtype='string', id=None),
#  'gleu_score': Value(dtype='float32', id=None)}

# %%
  train_ds[:5]
# Out:
# {'alignment_label': [1, 0, 0, 0, 0],
#  'normal_sentence_id': ['0_66252-1-0-0',
#   '0_66252-1-0-1',
#   '0_66252-1-0-2',
#   '0_66252-1-0-3',
#   '0_66252-1-0-4'],
#  'simple_sentence_id': ['0_66252-0-0-0',
#   '0_66252-0-0-0',
#   '0_66252-0-0-0',
#   '0_66252-0-0-0',
#   '0_66252-0-0-0'],
#  'normal_sentence': ['The Local Government Act 1985 is an Act of Parliament in the United Kingdom.',
#   'Its main effect was to abolish the six county councils of the metropolitan counties that had been set up in 1974, 11 years earlier, by the Local Government Act 1972, along with the Greater London Council that had been established in 1965.',
#   "In their place many single purpose authorities known collectively as 'joint authorities' were established for fire service, police and passenger transport.",
#   'An ad hoc education authority was established for Inner London and a planning authority for Greater London.',
#   "The legislation permitted councils to form 'joint arrangements' for waste disposal and other services that they wished to provide together."],
#  'simple_sentence': ['The Local Government Act 1985 was an Act of Parliament in the United Kingdom.',
#   'The Local Government Act 1985 was an Act of Parliament in the United Kingdom.',
#   'The Local Government Act 1985 was an Act of Parliament in the United Kingdom.',
#   'The Local Government Act 1985 was an Act of Parliament in the United Kingdom.',
#   'The Local Government Act 1985 was an Act of Parliament in the United Kingdom.'],
#  'gleu_score': [0.800000011920929,
#   0.08641975373029709,
#   0.012820512987673283,
#   0.032258063554763794,
#   0.013513513840734959]}

# %%
dataset.set_format(type="pandas")
df_train = dataset["train"][:]
df_test = dataset["test"][:]
df_dev = dataset["dev"][:]

# %%
df_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73249 entries, 0 to 73248
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   alignment_label     73249 non-null  int64
#  1   normal_sentence_id  73249 non-null  object
#  2   simple_sentence_id  73249 non-null  object
#  3   normal_sentence     73249 non-null  object
#  4   simple_sentence     73249 non-null  object
#  5   gleu_score          73249 non-null  float32
# dtypes: float32(1), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
# Class Distribution
import matplotlib.pyplot as plt

train_df["label_name"].value_counts(ascending=True).plot.barh()
plt.title("Category Counts");
